# %% [markdown]
# # 3. Sentiment Classification

# %%
import re
import numpy as np
import pandas as pd
import joblib
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score, f1_score

# %%
def fix_negations(text):
    text = str(text).lower()
    return re.sub(
        r"\b(not|no|never|without|don't|doesn't|didn't|isn't|aren't|wasn't|weren't|won't|wouldn't|couldn't|can't)\s+(\w+)",
        r"\1_\2", text)
 
df = pd.read_csv("../data/processed/cleaned_restaurant_reviews.csv")
 
def rating_to_sentiment(r):
    if r >= 4:
        return "positive"
    elif r == 3:
        return "neutral"
    return "negative"
 
df["sentiment_label"] = df["Rating"].apply(rating_to_sentiment)
print(df["sentiment_label"].value_counts())
# Out:
# sentiment_label
# positive    439
# negative     95
# neutral      53
# Name: count, dtype: int64

# %% [markdown]
# ### Train/Test Split

# %%
X_text = df["review_clean"].astype(str).apply(fix_negations)
y = df["sentiment_label"]
 
X_train, X_test, y_train, y_test = train_test_split(
    X_text, y, test_size=0.2, random_state=42, stratify=y
)
print("Train:", X_train.shape, " Test:", X_test.shape)
# Out:
# Train: (469,)  Test: (118,)

# %% [markdown]
# ### Vectorize with TF-IDF

# %%
tfidf = TfidfVectorizer(
    ngram_range=(1, 2),
    min_df=1,
    max_df=0.95,
    stop_words="english",
    sublinear_tf=True,
)
X_train_vec = tfidf.fit_transform(X_train)
X_test_vec = tfidf.transform(X_test)

# %% [markdown]
# ### Train the Logistic Regression classifier

# %%
clf = LogisticRegression(max_iter=1000, class_weight="balanced")
clf.fit(X_train_vec, y_train)
pred = clf.predict(X_test_vec)
 
print(classification_report(y_test, pred))
print("Accuracy:", accuracy_score(y_test, pred))
print("Macro F1:", f1_score(y_test, pred, average="macro"))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.65      0.68      0.67        19
#      neutral       0.22      0.18      0.20        11
#     positive       0.90      0.91      0.90        88
#
#     accuracy                           0.81       118
#    macro avg       0.59      0.59      0.59       118
# weighted avg       0.80      0.81      0.80       118
#
# Accuracy: 0.8050847457627118
# Macro F1: 0.5902071563088512

# %% [markdown]
# ### Cross-validate

# %%
cv_scores = cross_val_score(clf, tfidf.transform(X_text), y, cv=5, scoring="f1_macro")
print("5-fold CV Macro F1:", cv_scores.mean(), "+/-", cv_scores.std())
# Out:
# 5-fold CV Macro F1: 0.5326666021155267 +/- 0.06203585575251389

# %% [markdown]
# ### Inspect which words drive each prediction

# %%
feature_names = np.array(tfidf.get_feature_names_out())
for cls in clf.classes_:
    coefs = clf.coef_[list(clf.classes_).index(cls)]
    top_words = feature_names[np.argsort(coefs)[-10:]]
    print(f"Top words for '{cls}':", list(top_words))
# Out:
# Top words for 'negative': ['horrible', 'food average', 'experience', 'overpriced', 'experience disappointing', 'food', 'worst', 'average', 'disappointing', 'poor']
# Top words for 'neutral': ['food service', 'better', 'service great', 'floor', 'masala dosa', 'dosa', 'ambience service', 'poor slow', 'hype', 'lot']
# Top words for 'positive': ['great', 'visit', 'truffles', 'good', 'bangalore', 'loved', 'delicious', 'excellent', 'best', 'amazing']

# %% [markdown]
# ### Save the model + vectorizer

# %%
joblib.dump(tfidf, "../models/tfidf_vectorizer.pkl")
joblib.dump(clf, "../models/sentiment_classifier.pkl")
print("Saved.")
# Out:
# Saved.
