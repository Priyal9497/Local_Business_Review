# %% [markdown]
# # Topic Modeling (LDA)

# %% [markdown]
# ## 1. Project Configuration

# %%
import os, sys
try:
    _HERE = os.path.dirname(os.path.abspath(__file__))
except NameError:
    _HERE = os.getcwd()
for _c in (_HERE, os.path.dirname(_HERE)):
    _p = os.path.join(_c, "app")
    if os.path.isdir(_p):
        sys.path.insert(0, _p); break

# %%
import pandas as pd
import json
import gensim
from gensim import corpora
from gensim.models import CoherenceModel
import nltk
from nltk.corpus import stopwords
from text_utils import CLEAN_CSV, MODELS_DIR, tag_aspects, tokenize

# %% [markdown]
# ## 2. Data Loading

# %%
df = pd.read_csv(CLEAN_CSV)

# %% [markdown]
# ## 3. Rule-Based Aspect Tagging

# %%
# Rule-based tagging
tagged = df["Review text"].astype(str).apply(tag_aspects)
df["aspect"] = [t[0] for t in tagged]
df["aspect_conf"] = [round(t[2], 2) for t in tagged]

print("Aspect Distribution:")
print(df["aspect"].value_counts())
print("unmatched ('General'): %.1f%%" % ((df["aspect"] == "General").mean() * 100))

df.to_csv(CLEAN_CSV, index=False)
print("aspect column saved to: ", CLEAN_CSV)
# Out:
# Aspect Distribution:
# aspect
# Food        388
# Service      82
# General      75
# Price        19
# Ambience     13
# Name: count, dtype: int64
# unmatched ('General'): 13.0%
# aspect column saved to:  C:\Users\HP\Desktop\Local_Business_Review\Data\processed\cleaned_restaurant_reviews.csv

# %% [markdown]
# ## 4. Exploratory : Topic Modeling(LDA)

# %% [markdown]
# ### Setup & Preprocessing

# %%
nltk.download("stopwords", quiet=True)
from nltk.corpus import stopwords
STOP = set(stopwords.words("english"))

texts = [[w for w in tokenize(str(t))
          if w not in STOP and len(w) > 2 and not w.startswith("neg_")]
         for t in df["Review text"].tolist()]

# %% [markdown]
# ### Dictionary & Corpus Construction

# %%
dictionary = corpora.Dictionary(texts)
print("vocab before filter:", len(dictionary))
dictionary.filter_extremes(no_below=2, no_above=0.6)
print("vocab after  filter:", len(dictionary))

corpus = [dictionary.doc2bow(t) for t in texts]
print("empty documents:", sum(1 for c in corpus if not c))
# Out:
# vocab before filter: 1319
# vocab after  filter: 601
# empty documents: 0

# %% [markdown]
# ### Coherence Evaluation

# %%
scores = {}
for k in [3, 4, 5, 6]:
    m = gensim.models.LdaModel(corpus=corpus, id2word=dictionary, num_topics=k,
                               random_state=42, passes=15, alpha="auto")
    cm = CoherenceModel(model=m, texts=texts, dictionary=dictionary,
                        coherence="c_v", processes=1)      
    scores[k] = cm.get_coherence()
    print(f"k={k}  coherence={scores[k]:.4f}")

best_k = max(scores, key=scores.get)
# Out:
# k=3  coherence=0.2553
# k=4  coherence=0.2714
# k=5  coherence=0.2656
# k=6  coherence=0.2701

# %% [markdown]
# ### Train Final LDA Model

# %%
lda = gensim.models.LdaModel(corpus=corpus, id2word=dictionary, num_topics=best_k,
                             random_state=42, passes=15, alpha="auto")
print(f"\n=== TOPICS (k={best_k}) — paste these into your report ===")
for i, t in lda.print_topics(num_words=10):
    print(f"Topic {i}: {t}")
# Out:
# === TOPICS (k=4) — paste these into your report ===
# Topic 0: 0.075*"food" + 0.049*"service" + 0.040*"good" + 0.036*"great" + 0.029*"place" + 0.015*"restaurant" + 0.015*"taste" + 0.015*"delicious" + 0.015*"experience" + 0.014*"really"
# Topic 1: 0.043*"biryani" + 0.042*"chicken" + 0.027*"one" + 0.026*"food" + 0.025*"best" + 0.020*"service" + 0.019*"place" + 0.013*"bangalore" + 0.013*"good" + 0.011*"south"
# Topic 2: 0.037*"food" + 0.034*"dosa" + 0.027*"place" + 0.024*"good" + 0.019*"masala" + 0.017*"taste" + 0.012*"tried" + 0.011*"hype" + 0.011*"dose" + 0.010*"meghana"
# Topic 3: 0.043*"food" + 0.036*"experience" + 0.023*"staff" + 0.021*"service" + 0.018*"amazing" + 0.017*"place" + 0.017*"worth" + 0.017*"poor" + 0.015*"good" + 0.013*"dosa"

# %% [markdown]
# ## 5. Model Persistence

# %%
os.makedirs(MODELS_DIR, exist_ok=True)

#Save LDA artifacts
lda.save(os.path.join(MODELS_DIR, "lda_model.gensim"))
dictionary.save(os.path.join(MODELS_DIR, "lda_dictionary.gensim"))

#Generate and save topic labels
labels = {str(i): tag_aspects(" ".join(w for w, _ in lda.show_topic(i, 15)))[0] + f" (topic {i})"
          for i in range(best_k)}
with open(os.path.join(MODELS_DIR, "topic_labels.json"), "w") as f:
    json.dump(labels, f, indent=2)
print(json.dumps(labels, indent=2))
# Out:
# {
#   "0": "Food (topic 0)",
#   "1": "Food (topic 1)",
#   "2": "Food (topic 2)",
#   "3": "Service (topic 3)"
# }
