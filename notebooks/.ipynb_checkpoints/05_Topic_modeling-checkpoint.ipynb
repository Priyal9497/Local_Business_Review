# %% [markdown]
# # Topic Modeling (LDA)

# %%
import pandas as pd
import nltk
import gensim
from gensim import corpora

nltk.download("stopwords", quiet=True)
from nltk.corpus import stopwords

# %%
df = pd.read_csv("../data/processed/cleaned_restaurant_reviews.csv")
stop_words = set(stopwords.words("english"))

def tokenize(text):
    return [w for w in str(text).split() if w not in stop_words and len(w) > 2]

texts = df["review_clean"].apply(tokenize).tolist()
texts[:2]
# Out:
# [['good', 'ambience,', 'friendly', 'staff', 'great', 'food'],
#  ['food',
#   'vibe',
#   'must',
#   'try!',
#   'coconut',
#   'pudding',
#   'ultimate!',
#   'liked',
#   'biriyani!']]

# %% [markdown]
# ### Build dictionary and corpus

# %%
dictionary = corpora.Dictionary(texts)
dictionary.filter_extremes(no_below=3, no_above=0.5)
corpus = [dictionary.doc2bow(t) for t in texts]
print("Vocabulary size:", len(dictionary))
# Out:
# Vocabulary size: 411

# %% [markdown]
# ### Train the LDA model

# %%
num_topics = 5
lda_model = gensim.models.LdaModel(
    corpus=corpus, id2word=dictionary, num_topics=num_topics,
    random_state=42, passes=15, alpha="auto"
)

for idx, topic in lda_model.print_topics(num_words=8):
    print(f"Topic {idx}: {topic}")
# Out:
# Topic 0: 0.038*"food" + 0.028*"place" + 0.024*"great" + 0.018*"worth" + 0.015*"staff" + 0.014*"authentic" + 0.013*"loved" + 0.013*"delicious"
# Topic 1: 0.032*"biryani" + 0.031*"chicken" + 0.028*"masala" + 0.025*"one" + 0.023*"dosa" + 0.022*"special" + 0.021*"south" + 0.020*"tried"
# Topic 2: 0.055*"place" + 0.044*"best" + 0.033*"amazing" + 0.030*"dosa" + 0.026*"food" + 0.021*"one" + 0.018*"ever" + 0.018*"taste"
# Topic 3: 0.041*"great" + 0.034*"delicious" + 0.030*"experience" + 0.028*"absolutely" + 0.027*"dining" + 0.023*"food," + 0.019*"place" + 0.017*"service"
# Topic 4: 0.109*"food" + 0.066*"service" + 0.054*"good" + 0.025*"really" + 0.017*"experience" + 0.016*"excellent" + 0.014*"place" + 0.013*"restaurant"

# %% [markdown]
# ### Manually label each topic after reading the top words

# %%
topic_labels = {
    0: "TODO: label topic 0",
    1: "TODO: label topic 1",
    2: "TODO: label topic 2",
    3: "TODO: label topic 3",
    4: "TODO: label topic 4",
}
topic_labels
# Out:
# {0: 'TODO: label topic 0',
#  1: 'TODO: label topic 1',
#  2: 'TODO: label topic 2',
#  3: 'TODO: label topic 3',
#  4: 'TODO: label topic 4'}

# %% [markdown]
# ### Assign the dominant topic to each review

# %%
def get_dominant_topic(bow):
    topics = lda_model.get_document_topics(bow)
    return max(topics, key=lambda x: x[1])[0] if topics else None

df["dominant_topic"] = [get_dominant_topic(bow) for bow in corpus]
df["dominant_topic"].value_counts()
# Out:
# dominant_topic
# 4    210
# 2    116
# 1     99
# 0     98
# 3     64
# Name: count, dtype: int64

# %% [markdown]
# ### Save the model

# %%
lda_model.save("../models/lda_model.gensim")
dictionary.save("../models/lda_dictionary.gensim")
print("Saved.")
# Out:
# Saved.
